# %% [markdown]
#  Load data & test mapping

# %%
from pathlib import Path
import sys
import pandas as pd

_src = Path.cwd() / "notebooks" / "src"
if not _src.is_dir():
    _src = Path.cwd().parent / "notebooks" / "src"
sys.path.insert(0, str(_src))
from paths import PROJECT_ROOT
TAXONOMY_DIR = PROJECT_ROOT / "notebooks" / "src"
sys.path.insert(0, str(TAXONOMY_DIR))

from taxonomy import (
    ISSUE_TO_GENERAL,
    GENERAL_CATEGORIES,
    GENERAL_TO_MANUFACTURING,
    map_issue_to_general,
    map_issue_to_manufacturing,
)

print("taxonomy imported OK")
